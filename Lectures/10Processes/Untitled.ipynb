# %%
import plotly.express as px
from plotly import graph_objects as go
fig = go.Figure()
fig.add_trace(go.Funnel(x=[4500, 1500, 750, 500, 250], y=["Website visits", "Downloads", "Contacted by email", "Requested price", "Purchased"],textposition = "inside",textinfo = "value+percent total"))
fig.write_html('funnel.html')
fig.show()
# Out:
# <div>                            <div id="4a9f056e-52a6-41b7-a6a3-cebd308b2908" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4a9f056e-52a6-41b7-a6a3-cebd308b2908")) {                    Plotly.newPlot(                        "4a9f056e-52a6-41b7-a6a3-cebd308b2908",                        [{"textinfo":"value+percent total","textposition":"inside","x":[4500,1500,750,500,250],"y":["Website visits","Downloads","Contacted by email","Requested price","Purchased"],"type":"funnel"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.44444444444444
# ...

# %%
import seaborn as sns
import pandas as pd
dat = sns.load_dataset('mpg')
sns.scatterplot(datsort,x='weight',y='model_year',size='cylinders')
# Out:
# <Axes: xlabel='weight', ylabel='model_year'>

# %%
datsort=dat.sort_values(by = 'cylinders',ascending=True)
sns.scatterplot(datsort,x='weight',y='model_year',size='cylinders')
# Out:
# <Axes: xlabel='weight', ylabel='model_year'>

# %%
datsort=dat.sort_values(by = 'cylinders',ascending=False)
sns.scatterplot(datsort,x='weight',y='model_year',size='cylinders')
# Out:
# <Axes: xlabel='weight', ylabel='model_year'>

# %%
datsort
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 111  18.0          3          70.0        90.0    2124          13.5
# 71   19.0          3          70.0        97.0    2330          13.5
# 334  23.7          3          70.0       100.0    2420          12.5
# 243  21.5          3          80.0       110.0    2720          13.5
# 267  27.5          4         134.0        95.0    2560          14.2
# ..    ...        ...           ...         ...     ...           ...
# 86   14.0          8         304.0       150.0    3672          11.5
# 285  17.0          8         305.0       130.0    3840          15.4
# 286  17.6          8         302.0       129.0    3725          13.4
# 92   13.0          8         351.0       158.0    4363          13.0
# 0    18.0          8         307.0       130.0    3504          12.0
#
#      model_year origin                       name
# 111          73  japan                  maxda rx3
# ...
