# %%
import geopandas as gpd
aus = gpd.read_file('./data/SA4_2021_AUST_SHP_GDA2020') 
aus
# Out:
#     SA4_CODE21                            SA4_NAME21 CHG_FLAG21  CHG_LBL21  \
# 0          101                        Capital Region          0  No change
# 1          102                         Central Coast          0  No change
# 2          103                          Central West          0  No change
# 3          104               Coffs Harbour - Grafton          0  No change
# 4          105                    Far West and Orana          0  No change
# ..         ...                                   ...        ...        ...
# 103        899                No usual address (ACT)          0  No change
# 104        901                     Other Territories          0  No change
# 105        997  Migratory - Offshore - Shipping (OT)          0  No change
# 106        999                 No usual address (OT)          0  No change
# 107        ZZZ                     Outside Australia          1        New
#
#     GCC_CODE21                            GCC_NAME21 STE_CODE21  \
# ...
